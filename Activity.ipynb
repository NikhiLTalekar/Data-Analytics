# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhiLTalekar/Data-Analytics/blob/main/Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
X = [1,2,3,4,5]

Y = [10, 20, 25, 30, 40]
plt.plot(X, Y, marker='o',)
plt.xlable("x-axis")
plt.ylable("y-axis")
plt.title("Basic Line plot")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4cb43f454715> in <cell line: 0>()
#       4 Y = [10, 20, 25, 30, 40]
#       5 plt.plot(X, Y, marker='o',)
# ----> 6 plt.xlable("x-axis")
#       7 plt.ylable("y-axis")
#       8 plt.title("Basic Line plot")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
